# %%
import torch
import matplotlib.pylab as plt
# J峰之间的拉伸
data = torch.load('/root/zqh/NewDataSet/BCG_QJF1.pt')
for i in range(data.shape[0]):
    plt.plot(data[i][0][0:100].detach().numpy())
plt.show()
data = torch.load('/root/zqh/NewDataSet/BCG_QJF3.pt')
for i in range(data.shape[0]):
    plt.plot(data[i][0][0:100].detach().numpy())
plt.show()
