# %%
import torch
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from Toolkit import *

# data = torch.load('/root/zqh/BCGDataSet/modify_extract_Single_resolution_wcm612.pt')
data = torch.load('/root/zqh/BCGDataSet/modify_extract_Single_resolution_pa10.pt')
print(data.shape)
for i in range(30):
    plt.plot(data[i][0][0:100].detach().numpy())
plt.show()
# Out:
# torch.Size([33, 1, 900])
