# %%
import torch
import matplotlib.pylab as plt
# J峰之间的拉伸
data = torch.load('/root/zqh/NewDataSet/New_data_pa15.pt')
for i in range(data.shape[0]):
    plt.plot(data[i][0][0:100].detach().numpy())
plt.show()
