# %%
from scipy import signal
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
data = np.array(pd.read_csv('/root/zqh/Getian/wcm/B31F06840056A20C_7_ch2.csv'))[5000:15000,1:2]
data = data.reshape(data.shape[0])
# b, a = signal.butter(4, [0.6*2/125,8*2/125],'bandpass')
# filtedData = signal.filtfilt(b, a, data) #data为filtedData要过滤的信号
plt.plot(data[1:500]-data[0:499])
plt.show()
